# %%
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv("hiring.csv")
df
# Out:
#     experience  test_score  interview_score  salary
# 0            6          10                7   42089
# 1            4          10                5   42714
# 2            7           9                5   39159
# 3            2           5                5   30858
# 4            3          10                5   62870
# 5            8           9                9   31924
# 6            3           9                5   36205
# 7           10           8                7   42916
# 8            1           9                9   59855
# 9            8           9                8   64307
# 10           5           5                6   49148
# 11          10           5                8   35514
# 12           6           8                8   36306
# 13           4           6                6   63147
# 14           6           5                8   41780
# 15           5           6                5   36390
# 16           4           5                5   53668
# 17           3           6               10   32585
# 18           9           9                6   63527
# 19           1           8                7   53289

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['experience', 'test_score', 'interview_score']], df['salary'])
# Out:
# LinearRegression()

# %%
prediction1 = reg.predict(
    pd.DataFrame(
        [[2,9,6]],
        columns=['experience','test_score','interview_score']
    )
)

print(prediction1)
# Out:
# [49942.48668687]

# %%
prediction2 = reg.predict(
    pd.DataFrame(
        [[12,10,10]],
        columns=['experience','test_score','interview_score']
    )
)

print(prediction2)
# Out:
# [44436.46343902]

# %%
reg.coef_
# Out:
# array([-411.87373692, 1506.81354653, -723.52485629])

# %%
reg.intercept_
# Out:
# np.float64(41546.06137966378)
